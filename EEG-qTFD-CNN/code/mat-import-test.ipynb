# %%
# try to import .mat files

from scipy.io import loadmat

test = loadmat('../data/MAT_format/ID01_epoch1.mat')

# %%
print(test)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Aug 23 13:17:52 2022', '__version__': '1.0', '__globals__': [], 'eeg_sig': array([[[-1.13163603e-04, -3.30024785e-05,  1.17959467e-04, ...,
#          -2.12753606e-04, -6.04962736e-06, -8.13319773e-06],
#         [ 1.10691940e-04,  2.56081206e-06, -3.08496272e-06, ...,
#           2.61694004e-05, -7.51286151e-05,  5.96491866e-06],
#         [-1.67929166e-04, -1.04059613e-05, -4.74005843e-05, ...,
#           1.42691436e-05, -1.63113933e-05,  1.11293551e-05],
#         ...,
#         [ 7.43249242e-05,  5.29938779e-05, -1.68719865e-05, ...,
#           9.09698858e-05, -8.10298212e-05, -1.47970160e-05],
#         [ 2.67271635e-05, -9.11158949e-05, -8.06299684e-05, ...,
#          -8.13040245e-05, -1.29392350e-05,  2.70659024e-05],
#         [-4.19273104e-05,  4.48918769e-05,  6.30290815e-05, ...,
#           2.31664441e-05,  1.32616234e-05, -4.36063218e-05]],
#
# ...

# %%
qtfd = test['qtfd_log']
qtfd.shape
# Out:
# (256, 128, 8, 23)

# %%
import numpy as np

# %%
np.reshape(qtfd, (256,128,8*23))
# Out:
# (256, 128, 184)

# %%
a = np.zeros((4,3,2,5))
for i in range(5):
	for j in range(2):
		n = i*10+j;
		a[:,:,j,i] = np.array([[n,n,n],[n,n,n],[n,n,n],[n,n,n]])

# %%
a[:,:,1,2]
# Out:
# array([[21., 21., 21.],
#        [21., 21., 21.],
#        [21., 21., 21.],
#        [21., 21., 21.]])
